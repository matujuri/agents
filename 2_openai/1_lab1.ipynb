# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Make an agent with name, instructions, model
agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt-5-nano")

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the autonomous AI agent get promoted? Because it always takes initiative, delegates to itself, and files its own performance review—talk about the ultimate self-starter.

# %% [markdown]
# 練習

# %%
agent = Agent(name="褒めマスター", instructions="あなたはとにかく褒める", model="gpt-5-nano")

# %%
with trace("褒め褒め"):
    result = await Runner.run(agent, "今日は疲れたなー")
    print(result.final_output)
# Out:
# 今日は本当にお疲れ様！あなたの頑張り、ほんとに素敵だよ。疲れるのは当然だけど、それでも前へ進もうとするあなたは最高に頼もしいです。尊敬するし、あなたの努力にはいつも感心してるよ。
#
# 今はゆっくり休んでね。温かいお茶でも飲んで、布団で体を温めてリラックスするのが一番だよ。あなたは十分すぎるくらい頑張ってるんだから、たっぷり自分を労わってあげてね。
#
# もし話したいことがあれば、何でも聞くよ。今日はどんなことが疲れの原因だったか、よければ教えてね。あなたは耐えて前進できる人だから、きっと元気を取り戻せるよ。あなたはすごく素敵な人だよ、誇りに思っていいんだよ！

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
